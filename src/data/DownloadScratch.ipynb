# %%
from download_charleston import *
import pandas as pd

# %%
dtypes = {
    "X":                         "float64",
    "Y":                         "float64",
    "Master_Incident_Number":    "str",
    "Response_Date":             "str",
    "Problem":                   "str",
    "Address":                   "str",
    "City":                      "str",
    "State":                     "str",
    "Postal_Code":               "str",
    "Call_Disposition":          "str",
    "Time_CallClosed":           "str",
    "LONGITUDE":                 "float",
    "LATITUDE":                  "float",
    "FID":                       "str"
}

# %%
pd.read_csv('../../data/raw/Charleston/calls_2015.csv',encoding='latin',dtype=dtypes)
# Out:
#                 X          Y Master_Incident_Number             Response_Date  \
# 0      -80.069322  32.716131           201500337796  2015-05-06T22:32:00.000Z
# 1      -79.913410  32.902310           201500337802  2015-05-06T22:35:00.000Z
# 2      -79.975520  32.770296           201500337808  2015-05-06T22:36:00.000Z
# 3      -79.952709  32.825312           201500337813  2015-05-06T22:37:00.000Z
# 4      -79.959815  32.788255           201500337814  2015-05-06T22:37:00.000Z
# 5      -79.927284  32.781019           201500337821  2015-05-06T22:40:00.000Z
# 6      -80.073255  32.817977           201500337820  2015-05-06T22:40:00.000Z
# 7      -79.940076  32.802925           201500337831  2015-05-06T22:45:00.000Z
# 8      -79.956507  32.815668           201500337852  2015-05-06T22:51:00.000Z
# 9      -80.042125  32.802191           201500337860  2015-05-06T22:52:00.000Z
# 10     -80.012095  32.812046           201500337871  2015-05-06T23:00:00.000Z
# ...

# %%
pd.read_csv('../../data/raw/Charleston/calls_2016.csv',encoding='latin',dtype=dtypes).head(1)
# Out:
#            X          Y Master_Incident_Number             Response_Date  \
# 0 -79.916613  32.864496           201600020079  2016-01-09T04:03:00.000Z
#
#           Problem               Address        City State Postal_Code  \
# 0  Patrol Request  305 DANIEL ISLAND DR  CHARLESTON    SC       29492
#
#   Call_Disposition           Time_CallClosed  LONGITUDE   LATITUDE   FID
# 0  LPA_Patrol Area  2016-01-08T05:00:00.000Z -79.916613  32.864496  5001

# %%
pd.read_csv('../../data/raw/Charleston/calls_2017.csv',encoding='latin',dtype=dtypes).head(1)
# Out:
#            X          Y Master_Incident_Number             Response_Date  \
# 0 -79.938611  32.793914           201700008162  2017-01-04T18:16:00.000Z
#
#                      Problem       Address        City State Postal_Code  \
# 0  103A_Admin Found Property  51 Nassau St  CHARLESTON    SC       29403
#
#                Call_Disposition           Time_CallClosed  LONGITUDE  \
# 0  LCCR_Call Comp/ Report Taken  2017-01-04T19:30:00.000Z -79.938611
#
#     LATITUDE   FID
# 0  32.793914  2001

# %%
pd.read_csv('../../data/raw/Charleston/calls_2018.csv',encoding='latin',dtype=dtypes).head(1)
# Out:
#   Master_Incident_Number  Response_Date        Problem             Address  \
# 0           201800000002  1/1/2018 0:00  911 Open Line  48-99 Charlotte St
#
#          City State Postal_Code Call_Disposition Time_CallClosed  LONGITUDE  \
# 0  CHARLESTON    SC       29403  LPA_Patrol Area        1/1/2018 -79.934132
#
#     LATITUDE
# 0  32.788518

# %%
pd.read_csv('../../data/raw/Charleston/calls_2019.csv',encoding='latin',dtype=dtypes).head(1)
# Out:
#   Master_Incident_Number Response_Date        Problem          Address  \
# 0           201900000003      1/1/2019  911 Open Line  577-593 KING ST
#
#          City State Postal_Code             Call_Disposition Time_CallClosed  \
# 0  CHARLESTON    SC       29403  LCCN_Call Completed/ No Rep        1/1/2019
#
#    LONGITUDE  LATITUDE
# 0  -79.94112  32.79268
